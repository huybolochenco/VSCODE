# %%
#Bai 1
n=int(input("Nhập số nguyên n:"))
print("Số gấp đôi của n là:", n*2)

# %% [markdown]
# 18

# %%
# Bài 2
a = float(input("chiều rộng : "))
b = float(input("chiều dài : "))
S = a * b
m = s - ((b / 2)**2 * 3.14)
print("Diện tích trồng cây xanh là:",m)

# %% [markdown]
# Diện tích trồng cây xanh là: 20.38

# %%
# Bài 3
a = input("Nhập vào 1 ký tự:")
if a.isupper():
    print("Chữ thường tương ứng là:",a.lower())
elif a.islower():
    print("Chữ hoa tương ứng là:",a.upper())
else:
    print("Bạn đã nhập sai ký tự",a)

# %% [markdown]
# Chữ thường tương ứng là: c

# %%
# Bài 4
c = input("Nhập 1 ký tự: ")
if c.isalpha():
    print(f"{c} là ký tự alphabet")
else:
    print(f"{c} không phải là ký tự alphabet")

# %% [markdown]
# k là ký tự alphabet

# %%
# BÀi 5
A = input("Nhập vào một chữ cái hoa (A-Z): ")

if A == 'A':
    print("Chữ cái liền trước là: Z")
else:
    truoc = chr(ord(A) - 1)  
    print("Chữ cái liền trước là:", truoc)

# %% [markdown]
# Chữ cái liền trước là: X

# %%
# Bài 6
a = float(input("Nhập cạnh a: "))
b = float(input("Nhập cạnh b: "))
c = float(input("Nhập cạnh c: "))

if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    S = (p * (p - a) * (p - b) * (p - c)) ** 0.5
    print("Diện tích tam giác là:", round(S, 3))
else:
    print("3 cạnh này không tạo thành tam giác.")

# %% [markdown]
# Diện tích tam giác là: 34.197

# %%
#Bài 7
Chuỗi = input("Nhập vào 1 chuỗi")
if len(Chuỗi) < 20:
    print ("Chuỗi không đủ điều kiện! Phải nhập ít nhất 20 ký tự.")
else:
    stt5 = Chuỗi[4]
    stt9 = Chuỗi[8]
    print ("STT5 là:",stt5)
    print ("STT9 là:",stt9)

# %% [markdown]
# STT5 là : 5
# STT9 là : 9

# %%
#Bài 8
ten = input("Nhập tên chủ hộ: ")
cu = int(input("Chỉ số tháng trước: "))
moi = int(input("Chỉ số tháng này: "))
dien = moi - cu
if dien <= 50:
    tien = dien * 1984
elif dien <= 100:
    tien = 50 * 1984 + (dien - 50) * 2050
elif dien <= 200:
    tien = 50 * 1984 + 50 * 2050 + (dien - 100) * 2830
elif dien <= 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2830 + (dien - 200) * 2997
elif dien <= 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2830 + 100 * 2997 + (dien - 300) * 3350
else:
    tien = (50 * 1984 + 50 * 2050 + 100 * 2830 + 100 * 2997 + 100 * 3350 + (dien - 400) * 3460)
tong = round(tien * 1.08)
print(f"Họ và tên: {ten}")
print(f"Tiền phải trả: {tong} đồng")

# %% [markdown]
# Họ và tên: Nguyễn Xuân Thứ ;
# Tiền phải trả: 127062 đồng
