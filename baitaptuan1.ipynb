# %%
print("Hello World!")
Hello World!

# %%
ten_nguoi = input(" Dinh Gia Huy")
 Dinh Gia Huy
 print("Xin chao", "Dinh Gia Huy")
Xin chao Dinh Gia Huy

# %%
a1, b1, c1, a2, b2, a3 = 1, 2, 3, 4, 5, 6
>>> TB = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3) / 10
>>> print(round(TB,1))
4.2

# %%
a,b = map(int,input().split())
kq = a ** b
print(kq)
2:3
8

# %%
a=int
