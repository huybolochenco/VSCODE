# %%
# Bài 1
a = float(input("Chiều dài hình chữ nhật là:"))
b = float(input("Chiều rộng hình chữ nhật là:"))
if a > b and a != 0 and b != 0:
    print(f"Diện tích HCN là: {a * b}")
    print(f"CHu vi HCN là: {(a + b) * 2}")
else:
    print("Không phải là hình chữ nhật ")

# %% [markdown]
# Diện tích HCN là: 48.0
# CHu vi HCN là: 28.0

# %%
#bai2
n = float(input("Chiều rộng của hình tròn:"))
if n != 0 and n > 0:
    print(f"Diện tích hìnht tròn:{ n * n * 3.14 }")
    print(f"Chu vi hình tròn là: {2 * 3.14 * n}")
else:
    print("Bạn đã nhập sai giá trị !!!")

# %% [markdown]
# Diện tích hìnht tròn là: 153.86
# Chu vi hình tròn là: 43.96

# %%
# Bài 3
import math

a, b, c = map(float, input("Nhap a b c: ").split())
if a + b <= c or a + c <= b or b + c <= a:
    print("Ko là 3 cạnh của 1 tam giác")
else:
    if a == b == c:
        print("tam giác đều")
    elif a == b or a == c or b == c:
        print("Tam giác cân")
    elif a*a == b*b + c*c or b*b == a*a + c*c or c*c == a*a + b*b:
        print("Tam giác vuông")
    else:
        print("Tam giác thường")
  # chu vi tam giac
    P = a + b + c
    # dien tich tam giac theo pp heron
    p = P / 2
    S = math.sqrt(p * (p - a) * (p - b) * (p - c))

    print("Chu vi =", P)
    print("Diện tích =", S)

# %% [markdown]
# Chu vi = 15
# Diện tích = 6.495

# %%
# Bài 4
a, b = map(float, input("Nhập a b: ").split())
if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    x = -b / a
    print("Nghiệm x =", x)

# %% [markdown]
# Nghiệm x = -1.2

# %%
# Bài 5
import math
a, b, c = map(float, input("Nhập a b c: ").split())

if a == 0:
    # Phương trình bậc nhất: b*x + c = 0
    if b == 0:
        print("Vô nghiệm" if c != 0 else "Vô số nghiệm")
    else:
        print("Một nghiệm:", -c / b)
else:
    # Phương trình bậc hai
    delta = b*b - 4*a*c
    if delta < 0:
        print("Vô nghiệm")
    elif delta == 0:
        print("Nghiệm kép:", -b / (2*a))
    else:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        print("Hai nghiệm:", x1, x2)t

# %% [markdown]
# Hai nghiệm: 1.0 0.5

# %%
#Bài 6
a, b, c, d = map(int,input("Nhập vào các số:").split())
print("Giá trị lớn nhất là:",max(a,b,c,d))

# %% [markdown]
# Giá trị lớn nhất là: 19

# %%
#Bài 7
a, b, c, d = map(int,input("Nhập vào các số:").split())
print("Giá trị nhỏ nhất là:",min(a,b,c,d))

# %% [markdown]
# Giá trị nhỏ nhất là: 3

# %%
#baiBài 8
a,b,m,c,d,n = map(float,input("Nhập vào các gtrị của hệ pt:").split())
det = a * d-b * c
det1 = m * d-b * n
det2 = b * n - m * d
if det != 0:
    x = det1 / det
    y = det2 / det
    print("Hệ pt có nghiệm duy nhất:(x, y) =",(x,y))
else:
    if det1 != 0 or det2 != 0:
        print("Hệ pt vô nghiệm.")
    else:
        print("Hệ pt có VSN.")

# %% [markdown]
# Hệ pt có nghiệm duy nhất:(x, y) = (-1.0, 1.0)

# %%
n = int(input("Nhập giây"))
Phút = n/60
Giờ = Phút/60
Phutmoi = max(0,Phut - Gio*60)
Giaymoi = max(0,n - Gio3600 - Phutmoi*60)
print(Gio , "gio", Phutmoi , "phut", Giaymoi , "giay")

# %% [markdown]
# 1.0 gio 0 phut 0 giay

# %%
#bài 10
a,b = map(float,input("Nhap vao tam cua duong tron:").split())
r = float(input("Nhap vao ban kinh cua duong tron:"))
x,y = map(float,input("Nhap diem A:").split())
d = ((x - a) ** 2 + (y - b) ** 2) == r**2
if d <= r:
    print("Diem do thuoc duong tron.")
else:
    print("Diem do khong thuoc duong tron.")

# %% [markdown]
# diem A khong thuoc duong tron

# %%
#Bài 11
x,y = map(float, input("Nhập giá trị 2 số")).split()
print("Giá trị của kết quả là:", x**y)

# %% [markdown]
# Giá trị của kết quả là: 1024.80
