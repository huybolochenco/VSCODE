# %%
#W3A2
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
a = a ^ b
b = a ^ b
a = a ^ b
print("a =", a)
print("b =", b)

# %% [markdown]
#  a=3, b=5

# %%
#W3A4
m = float(input("Nhap vao mot so m:"))
n = float(input("Nhap vao mot so n"))
l = m // n
print(f"So lam tron xuong la:{l}")

# %% [markdown]
# So lam tron xuong la: 1.0

# %%
#W3A5
m = int(input("Nhap vao mot so m:"))
n = int(input("Nhap vao mot so n"))
g = m / n
l = m // n
k = g - l
if k > 0:
    print(f"So lam tron len la:{l + 1}")
else:
    print(l)

# %% [markdown]
# So lam tron len la: 4

# %%
#W3A6
x = int(input("Nhập 1 số nguyên dương:"))
if x%2==0:
    print("Even")
else:
    print("Odd")

# %% [markdown]
# Even

# %%
#W3A7
a=int(input("Nhap a:"))
b=int(input("Nhap b:"))
if (a+b > 0):   print("Yes")
else:
    print("No")

# %% [markdown]
# No

# %%
#8
a=str(input("Nhap chuoi a :"))
b=str(input("Nhap chuoi b :"))
if len(a) > len(b):
    print("True")
else: print("False")

# %% [markdown]
# True

# %%
#W3A9
a, b, c = map(float, input("Nhập lần lượt số đo 3 cạnh: ").split())
if a+b>c and b+c>a and a+c>b:
    print("Yes")
else:
    print("No")

# %% [markdown]
# Yes

# %%
#W3A10
a, b, c, d= map(int, input("Nhap 4 so a, b, c, d:").split(""))
s = min(a, b, c, d)
print(s)

number = [a, b, c, d]
min_num = number[0]
for i in number:
    if i < min_num:
        min_num = i
print(min_num)

# %% [markdown]
# 1

# %% [markdown]
# Nhap 4 so a, b, c, d: 4 5 1 2
# 1

# %%
#W3A11
a , b , c = map(int,input().split())
if (a > 0 and b > 0 and c > 0) and (a + b > c) and (a + c > b) and (b + c > a):
    if a == b and b == c:
        print("Tam giac deu")
    elif (a == b) or (b == c) or (a == c):
        print("Tam giac can")
    elif (a*a == b*b + c*c) or (b*b == a*a + c*c) or (c*c == a*a + c*c): 
        print("Tam giac vuong")
    else:
        print("Tam giac thuong")
else:
    print("Khong phai la tam giac")

# %% [markdown]
# Tam giac can

# %%
#W3A12
n = int(input('nhap nam:'))
if (n % 4 == 0 and n % 100 != 0) or n % 400 == 0:
    print('yes')
else:
    print('no')

# %% [markdown]
# no

# %%
#W3A13
a = float(input("Nhap a:"))
b = float(input("Nhap b:"))
if a == 0:
    if b == 0:
        print("Vo so nghiem")
    else:
        print("Vo nghiem")
else:
    x = - b / a
    print("nghiem cua phuong trinh la:",x)

# %% [markdown]
# nghiem cua phuong trinh la: 3.0

# %%
#W3A14
a, b = list(map(float, input("Nhập a, b trong ax + b = 0").split()))
if a==0:
    if b==0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    print(f"x = {-b/a}")

# %% [markdown]
# x= -0.75

# %%
#W3A16
a=float(input("a="))
a1=a+1
a2=a+0.5
print(int(a1), int(a), int(a2), end=" ")

# %% [markdown]
# 3

# %%
#W3A17
a, b, c, d =map(int, input("Nhap 4 so a, b, c, d:").split())
list_num = []
x=b/a
x1=c/b
x2=d/c
if x==x1==x2:
    print("Day la mot cap so nhan")
else:
    print("day khong phai la mot cap so nhan")

# %% [markdown]
# day khong phai la mot cap so nhan
